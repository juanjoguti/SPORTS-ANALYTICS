# %% [markdown]
# # Get players data from ongoing season
# Import libraries:

# %%
import requests
import pandas as pd
from football.constants.seasons import Seasons

# %% [markdown]
# Request data to the API (should be running at *http://127.0.0.1:8000/docs*):

# %%
response = requests.get(f'http://127.0.0.1:8000/v1/football/{Seasons.S2223}/players')

# %% [markdown]
# Convert from *JSON* to *DataFrame*:

# %%
data_season_22_23 = pd.DataFrame.from_dict(response.json())

# %% [markdown]
# # EDA

# %%
data_season_22_23.head()
# Out:
#               Player Nationality Position         Squad         Competition  \
# 0   Brenden Aaronson      us USA    MF,FW  Leeds United  eng Premier League
# 1   Yunis Abdelhamid      ma MAR       DF         Reims          fr Ligue 1
# 2      Himad Abdelli      fr FRA       MF        Angers          fr Ligue 1
# 3  Salis Abdul Samed      gh GHA       MF          Lens          fr Ligue 1
# 4    Laurent Abergel      fr FRA       MF       Lorient          fr Ligue 1
#
#       Age  Born  MP Starts    Min  ...   xG npxG  xAG npxG+xAG xG per 90  \
# 0  22-069  2000  15     15  1,271  ...  1.9  1.9  2.9      4.9      0.14
# 1  35-093  1987  16     16  1,440  ...  1.3  1.3  0.2      1.6      0.08
# 2  23-043  1999   8      3    321  ...  0.4  0.4  0.6      1.0      0.12
# 3  22-279  2000  16     16  1,439  ...  0.7  0.7  0.4      1.0      0.04
# 4  29-332  1993  11     11    886  ...  0.2  0.2  0.5      0.7      0.02
#
#   xAG per 90 xG+xAG per 90 npxG per 90 npxG+xAG per 90  Matches
# ...
